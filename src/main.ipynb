# %%
# !cd drive/MyDrive/EIT_KTC2023 && python main.py train --method cnn --num_epochs 200 --result_dir cnn_lr0.02_size4096 --batch_size 4096 --lr 0.02

# %%
# !cd drive/MyDrive/EIT_KTC2023 && python main.py train --method cnn --num_epochs 200 --result_dir cnn_lr0.0005_size128 --batch_size 128 --lr 0.0005
