# %%
# !python main.py train --method fno --config src/configs/fno_config.yaml --data_dir data --num_epochs 2 --result_dir fno
# Out:
# Loading config from: src/configs/fno_config.yaml
# Loaded 7 npz files from data\train
# Loaded 1 npz files from data\valid
# Training for 2 epochs
# Results will be saved to: results\fno_20251221_195252
#
# Epoch 1/2
# Train Loss: 0.065824, Val Loss: 0.035432
# Val Metrics: mse: 0.0354, mae: 0.1008, psnr: 14.5061, ssim: 0.0150, relative_error: 1.1639
# Learning Rate: 5.000000e-04
# Saved best model (val_loss: 0.035432)
#
# Epoch 2/2
# Train Loss: 0.064756, Val Loss: 0.033968
# Val Metrics: mse: 0.0340, mae: 0.0932, psnr: 14.6893, ssim: 0.0195, relative_error: 1.1396
# Learning Rate: 5.000000e-04
# Saved best model (val_loss: 0.033968)
#
# Training completed! Best validation loss: 0.033968
# 2025-12-21 19:52:52 - EIT_Training - INFO - Training method: fno
# ...

# %%
# !python main.py inference --method fno --config src/configs/fno_config.yaml --checkpoint results/.../best_model.pth

# %%
# !python main.py profile --method cnn
# Out:
# [CNN] 使用论文的CNN-EIM架构，输出尺寸: 128×128
# Method: cnn
# Parameters: 1,987,878 (7.58 MB)
# FLOPs (forward): 0.029 GFLOPs
# Avg inference time: 3.06 ms
# Results saved to: results\profile_cnn_1
# Warmup:   0%|          | 0/2 [00:00<?, ?it/s]
#
#
# Timing:   0%|          | 0/5 [00:00<?, ?it/s]

# %%
# !python main.py profile --method fno
# Out:
# Method: fno
# Parameters: 4,739,713 (36.08 MB)
# FLOPs (forward): 0.693 GFLOPs
# Avg inference time: 2.16 ms
# Results saved to: results\profile_fno_1
# Warmup:   0%|          | 0/2 [00:00<?, ?it/s]
#
#
# Timing:   0%|          | 0/5 [00:00<?, ?it/s]

# %%
# !python main.py train --method fno --config src/configs/fno_config.yaml --num_epochs 200 --result_dir fno
# Out:
# Loading config from: src/configs/fno_config.yaml
# 2025-12-22 20:40:27 - EIT_Training - INFO - Training method: fno
# 2025-12-22 20:40:27 - EIT_Training - INFO - Config: {'data': {'data_dir': 'data', 'batch_size': 64, 'num_workers': 4, 'pin_memory': True, 'use_eim': True}, 'training': {'num_epochs': 200, 'save_every': 20, 'device': 'cuda', 'method_name': 'fno'}, 'optimizer': {'type': 'adam', 'lr': 0.001, 'weight_decay': 1e-05, 'betas': [0.9, 0.999]}, 'scheduler': {'type': 'reduce_on_plateau', 'mode': 'min', 'factor': 0.5, 'patience': 15}, 'model': {'input_channels': 1, 'output_channels': 1, 'input_size': 16, 'output_size': 128, 'width': 64, 'depth': 4, 'modes1': 12, 'modes2': 12, 'add_coord': True}, 'method_name': 'fno'}
# 2025-12-22 20:40:27 - EIT_Training - INFO - Setting up data module...
# Loaded 46080 npz files from data/train
# Loaded 5760 npz files from data/valid
# 2025-12-22 20:40:27 - EIT_Training - INFO - Train dataset size: 46080
# ...

# %% [markdown]
# 5287mb

# %%
# !python main.py train --method fno --num_epochs 300 --result_dir fno_20251222_204027 --resume results/fno_20251222_204027/checkpoint_epoch_160.pth

# %%
# !python main.py train --method cnn --config src/configs/cnn_config.yaml --num_epochs 200 --result_dir cnn

# %%
# !python main.py inference --method fno --config src/configs/fno_config.yaml --checkpoint results/fno_20251222_204027/best_model.pth --dataset test2023

# %%
# !python main.py inference --method cnn --config src/configs/cnn_config.yaml --checkpoint results/cnn_20251225_110918/best_model.pth --dataset test2023

# %%
# !python main.py train --method diffusion --config src/configs/diffusion_config.yaml --num_epochs 200 --result_dir diffusion
